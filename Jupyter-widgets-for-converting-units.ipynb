# %%
from ipywidgets import interact, interactive, fixed, interact_manual
import numpy as np
import ipywidgets as widgets
from ipywidgets import HBox, VBox, Layout

header = widgets.HTML("<h3 class = 'text_left'><font color = 'green'>Calculate aliquot volume in mL</font>")
display(header)
                 

style = {'description_width': 'initial'}
interact_calc = interact_manual.options(manual_name="Calculate")
@interact_calc(wt = widgets.FloatText(description='Reagent Mass',style=style,layout=Layout(width='25%', margin='10px 100px 0px 5px')), 
               wtdrop = widgets.Dropdown(options=['μg','mg','g','kg'],description='Mass Unit',style=style,layout=Layout(width='15%', margin='0px 100px 25px 5px')), 
               mw = widgets.FloatText(description='Molecular Weight',style=style,layout=Layout(width='25%', margin='25px 100px 0px 5px')), 
               mwdrop = widgets.Dropdown(options=['g/mol','Da','kDa'],description='MW Unit',style=style,layout=Layout(width='15%', margin='0px 100px 25px 5px')), 
               aliconc = widgets.FloatText(description='Aliquot Concentration',style=style,layout=Layout(width='25%', margin='25px 100px 0px 5px')), 
               aliconcdrop = widgets.Dropdown(options=['μM','mM','M'],description='Conc. Unit',style=style,layout=Layout(width='15%', margin='0px 100px 40px 5px')))


def f(wt,wtdrop,mw,mwdrop,aliconc,aliconcdrop):
    if  (wtdrop == 'μg') & (mwdrop == 'g/mol') & (aliconcdrop == 'μM'):
        alivol = wt*1000/(mw*aliconc)
        
    elif (wtdrop == 'μg') & (mwdrop == 'Da') & (aliconcdrop == 'μM'):
        alivol = wt*1000/(mw*aliconc)
        
    elif (wtdrop == 'μg') & (mwdrop == 'kDa') & (aliconcdrop == 'μM'):
        alivol = wt/(mw*aliconc)
        
    elif (wtdrop == 'μg') & (mwdrop == 'g/mol') & (aliconcdrop == 'mM'):
        alivol = wt/(mw*aliconc)
        
    elif (wtdrop == 'μg') & (mwdrop == 'Da') & (aliconcdrop == 'mM'):
        alivol = wt/(mw*aliconc)
        
    elif (wtdrop == 'μg') & (mwdrop == 'kDa') & (aliconcdrop == 'mM'):
        alivol = wt/(mw*aliconc*1000)
    
    elif (wtdrop == 'μg') & (mwdrop == 'g/mol') & (aliconcdrop == 'M'):
        alivol = wt/(mw*aliconc*1000)
    
    elif (wtdrop == 'μg') & (mwdrop == 'Da') & (aliconcdrop == 'M'):
        alivol = wt/(mw*aliconc*1000)
    
    elif (wtdrop == 'μg') & (mwdrop == 'kDa') & (aliconcdrop == 'M'):
        alivol = wt/(mw*aliconc*10**6)
    
    elif (wtdrop == 'mg') & (mwdrop == 'g/mol') & (aliconcdrop == 'μM'):
        alivol = wt*10**6/(mw*aliconc)
    
    elif (wtdrop == 'mg') & (mwdrop == 'Da') & (aliconcdrop == 'μM'):
        alivol = wt*10**6/(mw*aliconc)
    
    elif (wtdrop == 'mg') & (mwdrop == 'kDa') & (aliconcdrop == 'μM'):
        alivol = wt*1000/(mw*aliconc)
    
    elif (wtdrop == 'mg') & (mwdrop == 'g/mol') & (aliconcdrop == 'mM'):
        alivol = wt*1000/(mw*aliconc)
        
    elif (wtdrop == 'mg') & (mwdrop == 'Da') & (aliconcdrop == 'mM'):
        alivol = wt*1000/(mw*aliconc)
        
    elif (wtdrop == 'mg') & (mwdrop == 'kDa') & (aliconcdrop == 'mM'):
        alivol = wt/(mw*aliconc)
    
    elif (wtdrop == 'mg') & (mwdrop == 'g/mol') & (aliconcdrop == 'M'):
        alivol = wt/(mw*aliconc)

    elif (wtdrop == 'mg') & (mwdrop == 'Da') & (aliconcdrop == 'M'):
        alivol = wt/(mw*aliconc)
    
    elif (wtdrop == 'mg') & (mwdrop == 'kDa') & (aliconcdrop == 'M'):
        alivol = wt/(mw*aliconc*1000)
    
    elif (wtdrop == 'g') & (mwdrop == 'g/mol') & (aliconcdrop == 'μM'):
        alivol = wt*10**9/(mw*aliconc)
    
    elif (wtdrop == 'g') & (mwdrop == 'Da') & (aliconcdrop == 'μM'):
        alivol = wt*10**9/(mw*aliconc)
        
    elif (wtdrop == 'g') & (mwdrop == 'kDa') & (aliconcdrop == 'μM'):
        alivol = wt*10**6/(mw*aliconc)
    
    elif (wtdrop == 'g') & (mwdrop == 'g/mol') & (aliconcdrop == 'mM'):
        alivol = wt*10**6/(mw*aliconc)
    
    elif (wtdrop == 'g') & (mwdrop == 'Da') & (aliconcdrop == 'mM'):
        alivol = wt*10**6/(mw*aliconc)
    
    elif (wtdrop == 'g') & (mwdrop == 'kDa') & (aliconcdrop == 'mM'):
        alivol = wt*1000/(mw*aliconc)
    
    elif (wtdrop == 'g') & (mwdrop == 'g/mol') & (aliconcdrop == 'M'):
        alivol = wt*1000/(mw*aliconc)
    
    elif (wtdrop == 'g') & (mwdrop == 'Da') & (aliconcdrop == 'M'):
        alivol = wt*1000/(mw*aliconc)
    
    elif (wtdrop == 'g') & (mwdrop == 'kDa') & (aliconcdrop == 'M'):
        alivol = wt/(mw*aliconc)
    
    elif (wtdrop == 'kg') & (mwdrop == 'g/mol') & (aliconcdrop == 'μM'):
        alivol = wt*10**12/(mw*aliconc)
    
    elif (wtdrop == 'kg') & (mwdrop == 'Da') & (aliconcdrop == 'μM'):
        alivol = wt*10**12/(mw*aliconc)
    
    elif (wtdrop == 'kg') & (mwdrop == 'kDa') & (aliconcdrop == 'μM'):
        alivol = wt*10**9/(mw*aliconc)
    
    elif (wtdrop == 'kg') & (mwdrop == 'g/mol') & (aliconcdrop == 'mM'):
        alivol = wt*10**9/(mw*aliconc)
    
    elif (wtdrop == 'kg') & (mwdrop == 'Da') & (aliconcdrop == 'mM'):
        alivol = wt*10**9/(mw*aliconc)
    
    elif (wtdrop == 'kg') & (mwdrop == 'kDa') & (aliconcdrop == 'mM'):
        alivol = wt*10**6/(mw*aliconc)
    
    elif (wtdrop == 'kg') & (mwdrop == 'g/mol') & (aliconcdrop == 'M'):
        alivol = wt*10**6/(mw*aliconc)
    
    elif (wtdrop == 'kg') & (mwdrop == 'Da') & (aliconcdrop == 'M'):
        alivol = wt*10**6/(mw*aliconc)
    
    else:
        alivol = wt*1000/(mw*aliconc)   
        
    return alivol


    
#btn = widgets.Button(description='Calculate')
#display(btn)
#btn.on_click(f)
# Out:
# HTML(value="<h3 class = 'text_left'><font color = 'green'>Calculate aliquot volume in mL</font>")
# interactive(children=(FloatText(value=0.0, description='Reagent Mass', layout=Layout(margin='10px 100px 0px 5p…
